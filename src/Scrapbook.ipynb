# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import scrapbook as sb 
import pandas as pd
from IPython.display import TextDisplayObject

# %% [markdown]
# ## Regression Dataset

# %%
book = sb.read_notebooks('/Users/manasigude/Academics/Project(ABC_GAN)/ABC_GAN/Regression')

# %%
data = []
for nb in book.notebooks:
    nbList = [nb.papermill_dataframe.iloc[1]['value'],
              nb.papermill_dataframe.iloc[2]['value'],
              nb.papermill_dataframe.iloc[0]['value'],
              nb.papermill_dataframe.iloc[3]['value'],
              nb.scraps['Stats Model MSE'].data,
              nb.scraps['GAN Model MSE'].data,
              nb.scraps['ABC-GAN Model MSE'].data,
              nb.scraps['Stats Model MAE'].data,
              nb.scraps['GAN Model MAE'].data,
              nb.scraps['ABC-GAN Model MAE'].data,
              nb.scraps['Stats Model Manhattan Distance'].data,
              nb.scraps['GAN Model Manhattan Distance'].data,
              nb.scraps['ABC-GAN Model Manhattan Distance'].data,
              nb.scraps['Stats Model Euclidean distance'].data,
              nb.scraps['GAN Model Euclidean distance'].data,
              nb.scraps['ABC-GAN Model Euclidean distance'].data,
              nb.scraps['GAN Model n_epochs'].data,
              nb.scraps['ABC-GAN Model n_epochs'].data]        
    data.append(nbList)
df = pd.DataFrame(data, columns = ['Features','Sample Size','Mean','Variance',
                                   'Stats Model MSE','GAN MSE','ABC-GAN MSE',
                                   'Stats Model MAE','GAN MAE','ABC-GAN MAE',
                                   'Stats Manhattan Distance','GAN Manhattan Distance','ABC-GAN Manhattan Distance',
                                   'Stats Model Euclidean Distance','GAN Euclidean Distance','ABC-GAN Euclidean Distance',
                                    'GAN Model n_epochs','ABC-GAN Model n_epochs'])

# %%
df
# Out:
#     Features  Sample Size  Mean  Variance  Stats Model MSE   GAN MSE  \
# 0       10.0         10.0   1.0      1.00     1.305164e-30  0.057592
# 1       10.0         10.0   1.0      0.10     2.185873e-30  0.040203
# 2       10.0        100.0   0.0      0.10     2.005552e-07  0.000466
# 3       10.0        100.0   0.0      0.01     1.737442e-07  0.000103
# 4       10.0         10.0   1.0      0.01     7.494371e-31  0.007110
# 5       10.0         10.0   0.0      1.00     2.208965e-30  0.018799
# 6       10.0         10.0   0.0      0.10     9.051100e-31  0.002174
# 7       10.0         10.0   0.0      0.01     6.736325e-31  0.012250
# 8       10.0        100.0   1.0      1.00     2.425125e-07  0.000687
# 9       10.0        100.0   1.0      0.10     2.653106e-07  0.000013
# 10      10.0        100.0   1.0      0.01     2.305077e-07  0.000164
# 11      10.0        100.0   0.0      1.00     3.149531e-07  0.000040
#
#     ABC-GAN MSE  Stats Model MAE   GAN MAE  ABC-GAN MAE  \
# 0      0.010373     9.159340e-16  0.142590     0.076511
# 1      0.001667     1.203204e-15  0.154295     0.028625
# 2      0.000446     3.560385e-04  0.018080     0.014852
# 3      0.000711     3.147880e-04  0.008154     0.020486
# 4      0.043160     6.925016e-16  0.067745     0.171328
# 5      0.027951     1.276756e-15  0.115744     0.116498
# 6      0.012252     8.076873e-16  0.035557     0.085167
# 7      0.022349     6.536438e-16  0.090774     0.079355
# 8      0.000040     4.011834e-04  0.018908     0.004923
# 9      0.000306     4.143463e-04  0.002716     0.007959
# 10     0.000250     3.832314e-04  0.009393     0.012979
# 11     0.000379     4.475444e-04  0.004966     0.013870
#
#     Stats Manhattan Distance  GAN Manhattan Distance  \
# 0               9.159340e-15                1.425900
# 1               1.203204e-14                1.542948
# 2               3.560385e-02                1.808046
# 3               3.147880e-02                0.815351
# 4               6.925016e-15                0.677449
# 5               1.276756e-14                1.157437
# 6               8.076873e-15                0.355575
# 7               6.536438e-15                0.907740
# 8               4.011834e-02                1.890849
# 9               4.143463e-02                0.271591
# 10              3.832314e-02                0.939294
# 11              4.475444e-02                0.496583
#
#     ABC-GAN Manhattan Distance  Stats Model Euclidean Distance  \
# 0                     0.765106                    3.612706e-15
# 1                     0.286255                    4.675332e-15
# 2                     1.485200                    4.478339e-03
# 3                     2.048608                    4.168263e-03
# 4                     1.713283                    2.737585e-15
# 5                     1.164975                    4.699962e-15
# 6                     0.851666                    3.008505e-15
# 7                     0.793554                    2.595443e-15
# 8                     0.492296                    4.924556e-03
# 9                     0.795875                    5.150831e-03
# 10                    1.297864                    4.801122e-03
# 11                    1.387037                    5.612068e-03
#
#     GAN Euclidean Distance  ABC-GAN Euclidean Distance  GAN Model n_epochs  \
# 0                 0.758890                    0.321588                1185
# 1                 0.634015                    0.129036                 742
# 2                 0.215628                    0.211149                 842
# 3                 0.101558                    0.266613                 440
# 4                 0.265892                    0.656933                1085
# 5                 0.433259                    0.528549                 589
# 6                 0.147291                    0.350007                1462
# 7                 0.349745                    0.472750                 765
# 8                 0.261963                    0.063494                 487
# 9                 0.036137                    0.173451                1014
# 10                0.128009                    0.157266                 353
# 11                0.063014                    0.192673                 381
#
#     ABC-GAN Model n_epochs
# 0                      458
# 1                      606
# 2                      991
# 3                      596
# 4                      732
# 5                      337
# 6                      777
# 7                     1007
# 8                      429
# 9                      452
# 10                     250
# 11                     356

# %%
df.to_csv('regression_out.csv', index=False)
