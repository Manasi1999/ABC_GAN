# %%
import matplotlib.pyplot as plt 
import scrapbook as sb
import numpy as np
import seaborn as sns
x = [0,1,2]
y = [2*i*i for i in x]

# %%
ax1 = plt.plot(x,y)

# %%
ax2 = plt.plot(x,x)

# %%
def plotImportantResults(ax1,ax2):
    fig, axes = plt.subplots(1,2)
    axes[0]=display(ax1)
    axes[1]=ax2

# %%
plotImportantResults(ax1,ax2)

# %%
x = np.random.normal(0,1,size = 100)

# %%
fig,axs = plt.subplots(2,2)
axs[0,0].hist(x,bins=100,density=True)
sns.distplot(x,hist=False,ax=axs[0,0])
# Out:
# /Users/manasigude/opt/anaconda3/envs/papermill/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>
